# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

pose_model = YOLO("yolov8n-pose.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
pose_model.predict(
    source="/content/drive/MyDrive/CSC2427_SC549_PA_03/Video_clips/V_1.mp4",
    conf=0.4,
    save=True
)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/145) /content/drive/MyDrive/CSC2427_SC549_PA_03/Video_clips/V_1.mp4: 384x640 1 person, 344.7ms
# video 1/1 (frame 2/145) /content/drive/MyDrive/CSC2427_SC549_PA_03/Video_clips/V_1.mp4: 384x640 1 person, 144.7ms
# video 1/1 (frame 3/145) /content/drive/MyDrive/CSC2427_SC549_PA_03/Video_clips/V_1.mp4: 384x640 1 person, 149.9ms
# ...

# %%
pose_model.predict(
    source="/content/drive/MyDrive/CSC2427_SC549_PA_03/Video_clips/",
    conf=0.4,
    save=True
)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/6 (frame 1/145) /content/drive/MyDrive/CSC2427_SC549_PA_03/Video_clips/V_1.mp4: 384x640 1 person, 129.1ms
# video 1/6 (frame 2/145) /content/drive/MyDrive/CSC2427_SC549_PA_03/Video_clips/V_1.mp4: 384x640 1 person, 129.7ms
# video 1/6 (frame 3/145) /content/drive/MyDrive/CSC2427_SC549_PA_03/Video_clips/V_1.mp4: 384x640 1 person, 178.3ms
# ...

# %%
from IPython.display import HTML
from base64 import b64encode

video_path = "/content/runs/pose/predict/V_1.avi"

mp4 = open(video_path,'rb').read()
data_url = "data:video/avi;base64," + b64encode(mp4).decode()

HTML(f"""
<video width=600 controls>
  <source src="{data_url}" type="video/avi">
</video>
""")

# %%
# !ffmpeg -i /content/runs/pose/predict/V_1.avi \
        /content/runs/pose/predict/V_1.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
from IPython.display import HTML
from base64 import b64encode

video_path = "/content/runs/pose/predict/V_1.avi"

mp4 = open(video_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

HTML(f"""
<video width=600 controls>
  <source src="{data_url}" type="video/mp4">
</video>
""")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !ffmpeg -i /content/runs/pose/predict/V_1.avi \
        /content/runs/pose/predict/V_1.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
from IPython.display import HTML
from base64 import b64encode

video_path = "/content/runs/pose/predict/V_1.mp4"

mp4 = open(video_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

HTML(f"""
<video width=500 controls>
  <source src="{data_url}" type="video/mp4">
</video>
""")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !cp -r /content/runs/pose/predict \
      /content/drive/MyDrive/CSC2427_SC549_PA_03/Keypoint_detection_Results
